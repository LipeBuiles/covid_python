# %% [markdown]
# <a href="https://colab.research.google.com/github/elpinchepastel/covid_python/blob/master/covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install covid
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/59/73/a56355a172dcc3725f4af48160861d157ff69173670ee9499eb2d965d4e9/covid-2.3.0.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 8.7MB 8.2MB/s
# ...
#   Created wheel for covid: filename=covid-2.3.0-cp36-none-any.whl size=8441 sha256=db24cbd7871127c2ec18d79d426b0dc4cef1b90125abad8e559c5a38de113303
#   Stored in directory: /root/.cache/pip/wheels/77/cd/8a/87daba9dc6274aa4b705f29698faeafd0f51af78e29e984c1a
# Successfully built covid
# ...

# %%
from covid import Covid

# %%
covid = Covid()

# %%
print(covid.get_total_active_cases())
# Out:
# 6214423

# %%
print(covid.get_total_deaths())
# Out:
# 646837

# %%
print(covid.get_data())
# Out:
# [{'id': '18', 'country': 'US', 'confirmed': 4217126, 'active': 2819523, 'deaths': 146754, 'recovered': 1279414, 'latitude': 40.0, 'longitude': -100.0, 'last_update': 1595792097000}, {'id': '22', 'country': 'Brazil', 'confirmed': 2394513, 'active': 522705, 'deaths': 86449, 'recovered': 1785359, 'latitude': -14.235, 'longitude': -51.9253, 'last_update': 1595792097000}, {'id': '27', 'country': 'India', 'confirmed': 1385685, 'active': 468045, 'deaths': 32063, 'recovered': 885577, 'latitude': 20.593684, 'longitude': 78.96288, 'last_update': 1595792097000}, {'id': '14', 'country': 'Russia', 'confirmed': 811073, 'active': 198652, 'deaths': 13249, 'recovered': 599172, 'latitude': 61.524, 'longitude': 105.3188, 'last_update': 1595792097000}, {'id': '163', 'country': 'South Africa', 'confirmed': 434200, 'active': 164491, 'deaths': 6655, 'recovered': 263054, 'latitude': -30.5595, 'longitude': 22.9375, 'last_update': 1595792097000}, {'id': '20', 'country': 'Mexico', 'confirmed': 390516, 'active'
# ...

# %%
countries = covid.list_countries()
print(countries)
# Out:
# [{'id': '18', 'name': 'US'}, {'id': '22', 'name': 'Brazil'}, {'id': '27', 'name': 'India'}, {'id': '14', 'name': 'Russia'}, {'id': '163', 'name': 'South Africa'}, {'id': '20', 'name': 'Mexico'}, {'id': '23', 'name': 'Peru'}, {'id': '21', 'name': 'Chile'}, {'id': '17', 'name': 'United Kingdom'}, {'id': '97', 'name': 'Iran'}, {'id': '28', 'name': 'Pakistan'}, {'id': '19', 'name': 'Spain'}, {'id': '154', 'name': 'Saudi Arabia'}, {'id': '11', 'name': 'Italy'}, {'id': '24', 'name': 'Colombia'}, {'id': '177', 'name': 'Turkey'}, {'id': '40', 'name': 'Bangladesh'}, {'id': '7', 'name': 'France'}, {'id': '8', 'name': 'Germany'}, {'id': '35', 'name': 'Argentina'}, {'id': '3', 'name': 'Canada'}, {'id': '98', 'name': 'Iraq'}, {'id': '146', 'name': 'Qatar'}, {'id': '96', 'name': 'Indonesia'}, {'id': '74', 'name': 'Egypt'}, {'id': '4', 'name': 'China'}, {'id': '102', 'name': 'Kazakhstan'}, {'id': '143', 'name': 'Philippines'}, {'id': '73', 'name': 'Ecuador'}, {'id': '15', 'name': 'Sweden'}, {'id': 
# ...
